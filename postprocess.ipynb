# %% [markdown]
# close, volume, MA, volatility
#
# -> 일일 수익률, RVOL, 일일 수익률의 63일 평균, 일일 수익률의 63일 표준편차
#
# $r_t = \frac{S_t - S_{t-1}}{S_{t-1}}$
#
# $RVOL = \frac{V}{MA_{63}(V)}$
#
# $MA_{63}(r_t)$
#
# $\sigma_{r_t}$

# %%
import pandas as pd


# 1. S&P500 티커 목록 가져오기 (예시: Wikipedia 활용)
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
tables = pd.read_html(url)
sp500_df = tables[0]
sp500_tickers = sp500_df['Symbol'].tolist()


for ticker in sp500_tickers:
    try:
        df = pd.read_csv(f'./data/price/{ticker.upper()}_15yr_data.csv')
        df = df.drop([0, 1]).reset_index(drop=True)

        df['Close'] = pd.to_numeric(df['Close'], errors='coerce')
        df['Volume'] = pd.to_numeric(df['Volume'], errors='coerce')
        df['return'] = df['Close'].pct_change(1, fill_method=None)
        df['ma'] = df['return'].rolling(window=63).mean()
        df['vol'] = df['return'].rolling(window=63).std()
        df['rvol'] = df['Volume']/df['Volume'].rolling(window=63).mean()

        df.dropna(inplace=True)
        df.drop(columns = ['Open', 'High', 'Low', 'Close', 'Volume'], inplace=True)
        df.to_csv(f"./data/derived/{ticker.upper()}_der_data.csv")
        print(f"Postprocess success: {ticker.upper()}")
    except Exception as e:
        print(f'error processing {ticker}: {e}')
# Out:
# Postprocess success: MMM
# Postprocess success: AOS
# Postprocess success: ABT
# Postprocess success: ABBV
# Postprocess success: ACN
# Postprocess success: ADBE
# Postprocess success: AMD
# Postprocess success: AES
# Postprocess success: AFL
# Postprocess success: A
# Postprocess success: APD
# Postprocess success: ABNB
# Postprocess success: AKAM
# Postprocess success: ALB
# Postprocess success: ARE
# Postprocess success: ALGN
# Postprocess success: ALLE
# Postprocess success: LNT
# Postprocess success: ALL
# Postprocess success: GOOGL
# Postprocess success: GOOG
# Postprocess success: MO
# Postprocess success: AMZN
# Postprocess success: AMCR
# Postprocess success: AEE
# Postprocess success: AEP
# Postprocess success: AXP
# Postprocess success: AIG
# Postprocess success: AMT
# Postprocess success: AWK
# Postprocess success: AMP
# Postprocess success: AME
# Postprocess success: AMGN
# Postprocess success: APH
# Postprocess success: ADI
# Postprocess success: ANSS
# Postprocess success: AON
# Postprocess success: APA
# Postprocess success: APO
# Postprocess success: AAPL
# Postprocess success: AMAT
# Postprocess success: APTV
# Postprocess success: ACGL
# Postprocess success: ADM
# Postprocess success: ANET
# Postprocess success: AJG
# Postprocess success: AIZ
# Postprocess success: T
# Postprocess success: ATO
# Postprocess success: ADSK
# Postprocess success: ADP
# Postprocess success: AZO
# Postprocess success: AVB
# Postprocess success: AVY
# Postprocess success: AXON
# Postprocess success: BKR
# Postprocess success: BALL
# Postprocess success: BAC
# Postprocess success: BAX
# Postprocess success: BDX
# Postprocess success: BRK.B
# Postprocess success: BBY
# Postprocess success: TECH
# Postprocess success: BIIB
# Postprocess success: BLK
# Postprocess success: BX
# Postprocess success: BK
# Postprocess success: BA
# Postprocess success: BKNG
# Postprocess success: BWA
# Postprocess success: BSX
# Postprocess success: BMY
# Postprocess success: AVGO
# Postprocess success: BR
# Postprocess success: BRO
# Postprocess success: BF.B
# Postprocess success: BLDR
# Postprocess success: BG
# Postprocess success: BXP
# Postprocess success: CHRW
# Postprocess success: CDNS
# Postprocess success: CZR
# Postprocess success: CPT
# Postprocess success: CPB
# Postprocess success: COF
# Postprocess success: CAH
# Postprocess success: KMX
# Postprocess success: CCL
# Postprocess success: CARR
# Postprocess success: CAT
# Postprocess success: CBOE
# Postprocess success: CBRE
# Postprocess success: CDW
# Postprocess success: CE
# Postprocess success: COR
# Postprocess success: CNC
# Postprocess success: CNP
# Postprocess success: CF
# Postprocess success: CRL
# Postprocess success: SCHW
# Postprocess success: CHTR
# Postprocess success: CVX
# Postprocess success: CMG
# Postprocess success: CB
# Postprocess success: CHD
# Postprocess success: CI
# Postprocess success: CINF
# Postprocess success: CTAS
# Postprocess success: CSCO
# Postprocess success: C
# Postprocess success: CFG
# Postprocess success: CLX
# Postprocess success: CME
# Postprocess success: CMS
# Postprocess success: KO
# Postprocess success: CTSH
# Postprocess success: CL
# Postprocess success: CMCSA
# Postprocess success: CAG
# Postprocess success: COP
# Postprocess success: ED
# Postprocess success: STZ
# Postprocess success: CEG
# Postprocess success: COO
# Postprocess success: CPRT
# Postprocess success: GLW
# Postprocess success: CPAY
# Postprocess success: CTVA
# Postprocess success: CSGP
# Postprocess success: COST
# Postprocess success: CTRA
# Postprocess success: CRWD
# Postprocess success: CCI
# Postprocess success: CSX
# Postprocess success: CMI
# Postprocess success: CVS
# Postprocess success: DHR
# Postprocess success: DRI
# Postprocess success: DVA
# Postprocess success: DAY
# Postprocess success: DECK
# Postprocess success: DE
# Postprocess success: DELL
# Postprocess success: DAL
# Postprocess success: DVN
# Postprocess success: DXCM
# Postprocess success: FANG
# Postprocess success: DLR
# Postprocess success: DFS
# Postprocess success: DG
# Postprocess success: DLTR
# Postprocess success: D
# Postprocess success: DPZ
# Postprocess success: DOV
# Postprocess success: DOW
# Postprocess success: DHI
# Postprocess success: DTE
# Postprocess success: DUK
# Postprocess success: DD
# Postprocess success: EMN
# Postprocess success: ETN
# Postprocess success: EBAY
# Postprocess success: ECL
# Postprocess success: EIX
# Postprocess success: EW
# Postprocess success: EA
# Postprocess success: ELV
# Postprocess success: EMR
# Postprocess success: ENPH
# Postprocess success: ETR
# Postprocess success: EOG
# Postprocess success: EPAM
# Postprocess success: EQT
# Postprocess success: EFX
# Postprocess success: EQIX
# Postprocess success: EQR
# Postprocess success: ERIE
# Postprocess success: ESS
# Postprocess success: EL
# Postprocess success: EG
# Postprocess success: EVRG
# Postprocess success: ES
# Postprocess success: EXC
# Postprocess success: EXPE
# Postprocess success: EXPD
# Postprocess success: EXR
# Postprocess success: XOM
# Postprocess success: FFIV
# Postprocess success: FDS
# Postprocess success: FICO
# Postprocess success: FAST
# Postprocess success: FRT
# Postprocess success: FDX
# Postprocess success: FIS
# Postprocess success: FITB
# Postprocess success: FSLR
# Postprocess success: FE
# Postprocess success: FI
# Postprocess success: FMC
# Postprocess success: F
# Postprocess success: FTNT
# Postprocess success: FTV
# Postprocess success: FOXA
# Postprocess success: FOX
# Postprocess success: BEN
# Postprocess success: FCX
# Postprocess success: GRMN
# Postprocess success: IT
# Postprocess success: GE
# Postprocess success: GEHC
# Postprocess success: GEV
# Postprocess success: GEN
# Postprocess success: GNRC
# Postprocess success: GD
# Postprocess success: GIS
# Postprocess success: GM
# Postprocess success: GPC
# Postprocess success: GILD
# Postprocess success: GPN
# Postprocess success: GL
# Postprocess success: GDDY
# Postprocess success: GS
# Postprocess success: HAL
# Postprocess success: HIG
# Postprocess success: HAS
# Postprocess success: HCA
# Postprocess success: DOC
# Postprocess success: HSIC
# Postprocess success: HSY
# Postprocess success: HES
# Postprocess success: HPE
# Postprocess success: HLT
# Postprocess success: HOLX
# Postprocess success: HD
# Postprocess success: HON
# Postprocess success: HRL
# Postprocess success: HST
# Postprocess success: HWM
# Postprocess success: HPQ
# Postprocess success: HUBB
# Postprocess success: HUM
# Postprocess success: HBAN
# Postprocess success: HII
# Postprocess success: IBM
# Postprocess success: IEX
# Postprocess success: IDXX
# Postprocess success: ITW
# Postprocess success: INCY
# Postprocess success: IR
# Postprocess success: PODD
# Postprocess success: INTC
# Postprocess success: ICE
# Postprocess success: IFF
# Postprocess success: IP
# Postprocess success: IPG
# Postprocess success: INTU
# Postprocess success: ISRG
# Postprocess success: IVZ
# Postprocess success: INVH
# Postprocess success: IQV
# Postprocess success: IRM
# Postprocess success: JBHT
# Postprocess success: JBL
# Postprocess success: JKHY
# Postprocess success: J
# Postprocess success: JNJ
# Postprocess success: JCI
# Postprocess success: JPM
# Postprocess success: JNPR
# Postprocess success: K
# Postprocess success: KVUE
# Postprocess success: KDP
# Postprocess success: KEY
# Postprocess success: KEYS
# Postprocess success: KMB
# Postprocess success: KIM
# Postprocess success: KMI
# Postprocess success: KKR
# Postprocess success: KLAC
# Postprocess success: KHC
# Postprocess success: KR
# Postprocess success: LHX
# Postprocess success: LH
# Postprocess success: LRCX
# Postprocess success: LW
# Postprocess success: LVS
# Postprocess success: LDOS
# Postprocess success: LEN
# Postprocess success: LII
# Postprocess success: LLY
# Postprocess success: LIN
# Postprocess success: LYV
# Postprocess success: LKQ
# Postprocess success: LMT
# Postprocess success: L
# Postprocess success: LOW
# Postprocess success: LULU
# Postprocess success: LYB
# Postprocess success: MTB
# Postprocess success: MPC
# Postprocess success: MKTX
# Postprocess success: MAR
# Postprocess success: MMC
# Postprocess success: MLM
# Postprocess success: MAS
# Postprocess success: MA
# Postprocess success: MTCH
# Postprocess success: MKC
# Postprocess success: MCD
# Postprocess success: MCK
# Postprocess success: MDT
# Postprocess success: MRK
# Postprocess success: META
# Postprocess success: MET
# Postprocess success: MTD
# Postprocess success: MGM
# Postprocess success: MCHP
# Postprocess success: MU
# Postprocess success: MSFT
# Postprocess success: MAA
# Postprocess success: MRNA
# Postprocess success: MHK
# Postprocess success: MOH
# Postprocess success: TAP
# Postprocess success: MDLZ
# Postprocess success: MPWR
# Postprocess success: MNST
# Postprocess success: MCO
# Postprocess success: MS
# Postprocess success: MOS
# Postprocess success: MSI
# Postprocess success: MSCI
# Postprocess success: NDAQ
# Postprocess success: NTAP
# Postprocess success: NFLX
# Postprocess success: NEM
# Postprocess success: NWSA
# Postprocess success: NWS
# Postprocess success: NEE
# Postprocess success: NKE
# Postprocess success: NI
# Postprocess success: NDSN
# Postprocess success: NSC
# Postprocess success: NTRS
# Postprocess success: NOC
# Postprocess success: NCLH
# Postprocess success: NRG
# Postprocess success: NUE
# Postprocess success: NVDA
# Postprocess success: NVR
# Postprocess success: NXPI
# Postprocess success: ORLY
# Postprocess success: OXY
# Postprocess success: ODFL
# Postprocess success: OMC
# Postprocess success: ON
# Postprocess success: OKE
# Postprocess success: ORCL
# Postprocess success: OTIS
# Postprocess success: PCAR
# Postprocess success: PKG
# Postprocess success: PLTR
# Postprocess success: PANW
# Postprocess success: PARA
# Postprocess success: PH
# Postprocess success: PAYX
# Postprocess success: PAYC
# Postprocess success: PYPL
# Postprocess success: PNR
# Postprocess success: PEP
# Postprocess success: PFE
# Postprocess success: PCG
# Postprocess success: PM
# Postprocess success: PSX
# Postprocess success: PNW
# Postprocess success: PNC
# Postprocess success: POOL
# Postprocess success: PPG
# Postprocess success: PPL
# Postprocess success: PFG
# Postprocess success: PG
# Postprocess success: PGR
# Postprocess success: PLD
# Postprocess success: PRU
# Postprocess success: PEG
# Postprocess success: PTC
# Postprocess success: PSA
# Postprocess success: PHM
# Postprocess success: PWR
# Postprocess success: QCOM
# Postprocess success: DGX
# Postprocess success: RL
# Postprocess success: RJF
# Postprocess success: RTX
# Postprocess success: O
# Postprocess success: REG
# Postprocess success: REGN
# Postprocess success: RF
# Postprocess success: RSG
# Postprocess success: RMD
# Postprocess success: RVTY
# Postprocess success: ROK
# Postprocess success: ROL
# Postprocess success: ROP
# Postprocess success: ROST
# Postprocess success: RCL
# Postprocess success: SPGI
# Postprocess success: CRM
# Postprocess success: SBAC
# Postprocess success: SLB
# Postprocess success: STX
# Postprocess success: SRE
# Postprocess success: NOW
# Postprocess success: SHW
# Postprocess success: SPG
# Postprocess success: SWKS
# Postprocess success: SJM
# Postprocess success: SW
# Postprocess success: SNA
# Postprocess success: SOLV
# Postprocess success: SO
# Postprocess success: LUV
# Postprocess success: SWK
# Postprocess success: SBUX
# Postprocess success: STT
# Postprocess success: STLD
# Postprocess success: STE
# Postprocess success: SYK
# Postprocess success: SMCI
# Postprocess success: SYF
# Postprocess success: SNPS
# Postprocess success: SYY
# Postprocess success: TMUS
# Postprocess success: TROW
# Postprocess success: TTWO
# Postprocess success: TPR
# Postprocess success: TRGP
# Postprocess success: TGT
# Postprocess success: TEL
# Postprocess success: TDY
# Postprocess success: TFX
# Postprocess success: TER
# Postprocess success: TSLA
# Postprocess success: TXN
# Postprocess success: TPL
# Postprocess success: TXT
# Postprocess success: TMO
# Postprocess success: TJX
# Postprocess success: TSCO
# Postprocess success: TT
# Postprocess success: TDG
# Postprocess success: TRV
# Postprocess success: TRMB
# Postprocess success: TFC
# Postprocess success: TYL
# Postprocess success: TSN
# Postprocess success: USB
# Postprocess success: UBER
# Postprocess success: UDR
# Postprocess success: ULTA
# Postprocess success: UNP
# Postprocess success: UAL
# Postprocess success: UPS
# Postprocess success: URI
# Postprocess success: UNH
# Postprocess success: UHS
# Postprocess success: VLO
# Postprocess success: VTR
# Postprocess success: VLTO
# Postprocess success: VRSN
# Postprocess success: VRSK
# Postprocess success: VZ
# Postprocess success: VRTX
# Postprocess success: VTRS
# Postprocess success: VICI
# Postprocess success: V
# Postprocess success: VST
# Postprocess success: VMC
# Postprocess success: WRB
# Postprocess success: GWW
# Postprocess success: WAB
# Postprocess success: WBA
# Postprocess success: WMT
# Postprocess success: DIS
# Postprocess success: WBD
# Postprocess success: WM
# Postprocess success: WAT
# Postprocess success: WEC
# Postprocess success: WFC
# Postprocess success: WELL
# Postprocess success: WST
# Postprocess success: WDC
# Postprocess success: WY
# Postprocess success: WMB
# Postprocess success: WTW
# Postprocess success: WDAY
# Postprocess success: WYNN
# Postprocess success: XEL
# Postprocess success: XYL
# Postprocess success: YUM
# Postprocess success: ZBRA
# Postprocess success: ZBH
# Postprocess success: ZTS

# %%
import random


def generate_scenario(n:int, k:int):
    # Number of stocks to select

    # Randomly select n stocks from the S&P 500 tickers
    selected_tickers = random.sample(sp500_tickers, n)

    # Initialize an empty DataFrame to store the concatenated data
    concatenated_df = pd.DataFrame()

    # Iterate over the selected tickers
    for i, ticker in enumerate(selected_tickers):
        try:
            # Read the derived data for the ticker
            df = pd.read_csv(f'./data/derived/{ticker.upper()}_der_data.csv')
            # Drop rows with any NaN values
            if df.isna().any().any():
                print(f'Skipping {ticker} due to NaN values')
                return 0
            
            # Rename the columns to include the stock identifier
            df = df.rename(columns={
                'return': f'S{i+1}_return',
                'ma': f'S{i+1}_ma',
                'vol': f'S{i+1}_vol',
                'rvol': f'S{i+1}_rvol'
            })
            
            # Set 'Price' as the index for joining on the same date
            df['Date'] = pd.to_datetime(df['Price'])
            df = df.set_index('Date')
            df = df.drop(columns=['Unnamed: 0', 'Price'], errors='ignore')
            # If concatenated_df is empty, initialize it with the current df
            if concatenated_df.empty:
                concatenated_df = df
            else:
                # Perform an outer join with the current df on the 'Date' index
                concatenated_df = concatenated_df.join(df, how='outer')
        
        except Exception as e:
            print(f'Error processing {ticker}: {e}')

    # Drop any columns that are duplicated due to the index or unnamed columns
    concatenated_df = concatenated_df.loc[:, ~concatenated_df.columns.duplicated()]

    # Filter the data to leave only consecutive one year data
    # Assuming the data is sorted by date and the 'Date' column is present
    concatenated_df = concatenated_df.reset_index()
    
    # Randomly select a year between 2008 and 2023
    random_year = random.randint(2008, 2023)
    
    # Define the start and end date for the randomly selected year
    start_date = f'{random_year}-01-01'
    end_date = f'{random_year}-12-31'

    # Filter the DataFrame for the specified one-year period
    one_year_data = concatenated_df.loc[(concatenated_df['Date'] >= start_date) & (concatenated_df['Date'] <= end_date)]
    
    # Check if the number of rows is fewer than 250
    if len(one_year_data) < 250:
        # Truncate the DataFrame
        one_year_data = pd.DataFrame()
        return 0
    # Read the macro data
    macro_df = pd.read_csv('./data/macro_15yr_data.csv')
    
    # Convert 'Date' column to datetime
    macro_df['Date'] = pd.to_datetime(macro_df['Date'])
    
    # Set 'Date' as the index for joining
    macro_df = macro_df.set_index('Date')
    
    # Perform an inner join with the macro data on the 'Date' index
    one_year_data = one_year_data.set_index('Date').join(macro_df, how='inner').reset_index()
    
    # Check for NA values
    if one_year_data.isna().any().any():
        return 0
    
    # Save the data to CSV if no NA values are present
    one_year_data.to_csv(f"./data/train_set/{k}.csv", index=False)
    return 1

# %%
n = 10

i = 0 

while i<10000:
    i += generate_scenario(n, i)
    if i % 100 == 99:
        print(f"{i+1}th scenatio generated")
# Out:
# 100th scenatio generated
# 200th scenatio generated
# 300th scenatio generated
# 400th scenatio generated
# 400th scenatio generated
# 500th scenatio generated
# 500th scenatio generated
# 500th scenatio generated
# 600th scenatio generated
# 700th scenatio generated
# 700th scenatio generated
# 800th scenatio generated
# 900th scenatio generated
# 1000th scenatio generated
# 1000th scenatio generated
# 1100th scenatio generated
# 1200th scenatio generated
# 1300th scenatio generated
# 1300th scenatio generated
# 1400th scenatio generated
# 1400th scenatio generated
# 1500th scenatio generated
# 1600th scenatio generated
# 1600th scenatio generated
# 1700th scenatio generated
# Error processing BF.B: columns overlap but no suffix specified: Index(['Adj Close'], dtype='object')
# 1800th scenatio generated
# 1800th scenatio generated
# 1800th scenatio generated
# 1800th scenatio generated
# Error processing BF.B: columns overlap but no suffix specified: Index(['Adj Close'], dtype='object')
# 1900th scenatio generated
# 1900th scenatio generated
# 2000th scenatio generated
# 2100th scenatio generated
# 2200th scenatio generated
# 2200th scenatio generated
# 2300th scenatio generated
# 2300th scenatio generated
# 2300th scenatio generated
# 2400th scenatio generated
# 2400th scenatio generated
# 2500th scenatio generated
# 2500th scenatio generated
# 2500th scenatio generated
# 2500th scenatio generated
# 2600th scenatio generated
# 2600th scenatio generated
# 2600th scenatio generated
# 2700th scenatio generated
# 2700th scenatio generated
# 2700th scenatio generated
# 2800th scenatio generated
# 2900th scenatio generated
# 3000th scenatio generated
# Error processing BRK.B: columns overlap but no suffix specified: Index(['Adj Close'], dtype='object')
# 3100th scenatio generated
# 3200th scenatio generated
# 3200th scenatio generated
# 3300th scenatio generated
# 3400th scenatio generated
# 3400th scenatio generated
# 3400th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3500th scenatio generated
# 3600th scenatio generated
# 3600th scenatio generated
# 3600th scenatio generated
# 3700th scenatio generated
# 3700th scenatio generated
# 3800th scenatio generated
# 3800th scenatio generated
# 3800th scenatio generated
# 3800th scenatio generated
# 3900th scenatio generated
# 4000th scenatio generated
# 4000th scenatio generated
# 4000th scenatio generated
# 4100th scenatio generated
# 4200th scenatio generated
# 4300th scenatio generated
# 4400th scenatio generated
# 4400th scenatio generated
# 4500th scenatio generated
# 4600th scenatio generated
# 4700th scenatio generated
# 4700th scenatio generated
# 4800th scenatio generated
# 4800th scenatio generated
# 4800th scenatio generated
# 4900th scenatio generated
# 4900th scenatio generated
# 5000th scenatio generated
# 5100th scenatio generated
# 5100th scenatio generated
# 5200th scenatio generated
# 5300th scenatio generated
# 5400th scenatio generated
# 5400th scenatio generated
# 5500th scenatio generated
# 5500th scenatio generated
# 5600th scenatio generated
# 5700th scenatio generated
# 5800th scenatio generated
# 5800th scenatio generated
# 5800th scenatio generated
# 5900th scenatio generated
# 5900th scenatio generated
# 6000th scenatio generated
# 6100th scenatio generated
# 6200th scenatio generated
# 6300th scenatio generated
# 6300th scenatio generated
# 6300th scenatio generated
# 6300th scenatio generated
# 6400th scenatio generated
# 6500th scenatio generated
# 6500th scenatio generated
# 6600th scenatio generated
# 6700th scenatio generated
# 6700th scenatio generated
# 6700th scenatio generated
# Error processing BF.B: columns overlap but no suffix specified: Index(['Adj Close'], dtype='object')
# 6800th scenatio generated
# 6900th scenatio generated
# 6900th scenatio generated
# 6900th scenatio generated
# 6900th scenatio generated
# 7000th scenatio generated
# 7100th scenatio generated
# 7100th scenatio generated
# 7200th scenatio generated
# 7200th scenatio generated
# 7300th scenatio generated
# 7400th scenatio generated
# 7400th scenatio generated
# 7400th scenatio generated
# 7500th scenatio generated
# 7500th scenatio generated
# 7600th scenatio generated
# 7700th scenatio generated
# 7700th scenatio generated
# 7800th scenatio generated
# 7900th scenatio generated
# 8000th scenatio generated
# 8000th scenatio generated
# 8100th scenatio generated
# 8200th scenatio generated
# 8200th scenatio generated
# 8300th scenatio generated
# 8400th scenatio generated
# 8500th scenatio generated
# 8500th scenatio generated
# 8600th scenatio generated
# 8600th scenatio generated
# 8600th scenatio generated
# 8600th scenatio generated
# 8600th scenatio generated
# 8700th scenatio generated
# 8700th scenatio generated
# 8700th scenatio generated
# 8800th scenatio generated
# 8800th scenatio generated
# 8800th scenatio generated
# 8800th scenatio generated
# 8900th scenatio generated
# 9000th scenatio generated
# 9000th scenatio generated
# 9000th scenatio generated
# 9000th scenatio generated
# 9100th scenatio generated
# 9200th scenatio generated
# 9300th scenatio generated
# 9300th scenatio generated
# 9400th scenatio generated
# 9400th scenatio generated
# 9400th scenatio generated
# 9400th scenatio generated
# 9500th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9600th scenatio generated
# 9700th scenatio generated
# 9700th scenatio generated
# 9800th scenatio generated
# 9800th scenatio generated
# 9900th scenatio generated
# 10000th scenatio generated

# %% [markdown]
# # Data set 구축
#
# - 10개의 주식 pool을 만든다.
#     - 10개의 조합은 다양하게 구성될 수 있으므로 $_{500}C_{10}$의 경우의 수 존재, random selection
#     - 1년 단위로 구성해야하기 때문에 매년 1월 1일부터 12월 31일까지의 데이터가 모두 존재하는 segment를 쪼갠다
#     - 같은 연도의 segment 500개 중 10개씩을 random sampling한다.
#     - 한 연도에 max 1000개정도? 로 test set을 구축한다
#     - VIX 지수와 금리 데이터를 test set에 붙인다

# %%
import pandas as pd

snp_tickers = ['AAPL', 'NVDA', 'MSFT', 'AMZN', 'GOOGL', 'AVGO', 'TSLA', 'GOOG', 'JPM', 'LLY']
for ticker in snp_tickers:
    df = pd.read_csv(f'./data/derived/{ticker.upper()}_der_data.csv')
    print(ticker)
    print(df.iloc[0, 1])
    nan_indices = df[df.isna().any(axis=1)].index
    print("NaN이 있는 인덱스:", nan_indices.tolist())
# Out:
# AAPL
# 2008-04-03
# NaN이 있는 인덱스: []
# NVDA
# 2008-04-03
# NaN이 있는 인덱스: []
# MSFT
# 2008-04-03
# NaN이 있는 인덱스: []
# AMZN
# 2008-04-03
# NaN이 있는 인덱스: []
# GOOGL
# 2008-04-03
# NaN이 있는 인덱스: []
# AVGO
# 2009-11-04
# NaN이 있는 인덱스: []
# TSLA
# 2010-09-28
# NaN이 있는 인덱스: []
# GOOG
# 2008-04-03
# NaN이 있는 인덱스: []
# JPM
# 2008-04-03
# NaN이 있는 인덱스: []
# LLY
# 2008-04-03
# NaN이 있는 인덱스: []
